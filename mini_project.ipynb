# %% [markdown]
# # Mini Project

# %% [markdown]
# ### Import required modules

# %%
import pprint
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

pp = pprint.PrettyPrinter()
plt.style.use('ggplot')
plt.rcParams['figure.dpi'] = 150

# %% [markdown]
# ### 1) Download the close prices for the constituents of Sensex.

# %%
#Sensex constituents list
mkts_list = [
  'ASIANPAINT.BO','AXISBANK.BO','BAJAJ-AUTO.BO','BAJFINANCE.BO','BAJAJFINSV.BO','BHARTIARTL.BO', 'DRREDDY.BO','HCLTECH.BO',
  'HDFC.BO', 'HDFCBANK.BO','HINDUNILVR.BO','ICICIBANK.BO','INDUSINDBK.BO','INFY.BO','ITC.BO','KOTAKBANK.BO','LT.BO','M&M.BO',
  'MARUTI.BO','NESTLEIND.BO', 'NTPC.BO','ONGC.BO','POWERGRID.BO','RELIANCE.BO','SBIN.BO','SUNPHARMA.BO','TCS.BO','TECHM.BO',
  'TITAN.BO','ULTRACEMCO.BO'
]

df_mkts = yf.download(tickers=mkts_list)['Adj Close']
df_mkts.head()
# Out:
# [*********************100%***********************]  30 of 30 completed
#             ASIANPAINT.BO  AXISBANK.BO  BAJAJ-AUTO.BO  BAJAJFINSV.BO  \
# Date
# 1991-01-04            NaN          NaN            NaN            NaN
# 1991-01-08            NaN          NaN            NaN            NaN
# 1991-01-10            NaN          NaN            NaN            NaN
# 1991-01-15            NaN          NaN            NaN            NaN
# 1991-01-16            NaN          NaN            NaN            NaN
#
#             BAJFINANCE.BO  BHARTIARTL.BO  DRREDDY.BO  HCLTECH.BO  HDFC.BO  \
# Date
# 1991-01-04            NaN            NaN         NaN         NaN      NaN
# 1991-01-08            NaN            NaN         NaN         NaN      NaN
# 1991-01-10            NaN            NaN         NaN         NaN      NaN
# 1991-01-15            NaN            NaN         NaN         NaN      NaN
# 1991-01-16            NaN            NaN         NaN         NaN      NaN
#
# ...

# %% [markdown]
# ### 2. Print start dates of all markets from when the price is not null

# %%
start_dates = {}

def print_start_date(column):
  ## this is a hint
  x = column.notnull()
  


pp.pprint(start_dates)
# Out:
# {'ASIANPAINT.BO': '2000-03-01',
#  'AXISBANK.BO': '1998-27-11',
#  'BAJAJ-AUTO.BO': '2008-26-05',
#  'BAJAJFINSV.BO': '2000-03-01',
#  'BAJFINANCE.BO': '2000-10-03',
#  'BHARTIARTL.BO': '2002-20-02',
#  'DRREDDY.BO': '1992-04-03',
#  'HCLTECH.BO': '2000-03-01',
#  'HDFC.BO': '2000-03-01',
#  'HDFCBANK.BO': '1995-01-06',
#  'HINDUNILVR.BO': '1991-04-01',
#  'ICICIBANK.BO': '2000-03-01',
#  'INDUSINDBK.BO': '2002-14-01',
#  'INFY.BO': '1995-11-05',
#  'ITC.BO': '1991-04-01',
#  'KOTAKBANK.BO': '1996-18-03',
#  'LT.BO': '1991-04-01',
#  'M&M.BO': '1991-04-01',
#  'MARUTI.BO': '2003-09-07',
#  'NESTLEIND.BO': '1991-04-01',
#  'NTPC.BO': '2004-05-11',
#  'ONGC.BO': '1996-18-03',
#  'POWERGRID.BO': '2007-05-10',
#  'RELIANCE.BO': '1995-10-07',
#  'SBIN.BO': '1995-11-05',
#  'SUNPHARMA.BO': '1994-26-12',
#  'TCS.BO': '2002-14-01',
#  'TECHM.BO': '2006-28-08',
#  'TITAN.BO': '1995-11-05',
#  'ULTRACEMCO.BO': '2000-03-01'}

# %% [markdown]
# ### 3. Forward fill NaN and drop the remaining rows that have NaN

# %%
df_mkts = df_mkts.fillna(_____)
## drop the remaining rows
_________________________________

## Print the start dates again
df_mkts.apply(print_start_date)
pp.pprint(start_dates)
# Out:
# {'ASIANPAINT.BO': '2008-26-05',
#  'AXISBANK.BO': '2008-26-05',
#  'BAJAJ-AUTO.BO': '2008-26-05',
#  'BAJAJFINSV.BO': '2008-26-05',
#  'BAJFINANCE.BO': '2008-26-05',
#  'BHARTIARTL.BO': '2008-26-05',
#  'DRREDDY.BO': '2008-26-05',
#  'HCLTECH.BO': '2008-26-05',
#  'HDFC.BO': '2008-26-05',
#  'HDFCBANK.BO': '2008-26-05',
#  'HINDUNILVR.BO': '2008-26-05',
#  'ICICIBANK.BO': '2008-26-05',
#  'INDUSINDBK.BO': '2008-26-05',
#  'INFY.BO': '2008-26-05',
#  'ITC.BO': '2008-26-05',
#  'KOTAKBANK.BO': '2008-26-05',
#  'LT.BO': '2008-26-05',
#  'M&M.BO': '2008-26-05',
#  'MARUTI.BO': '2008-26-05',
#  'NESTLEIND.BO': '2008-26-05',
#  'NTPC.BO': '2008-26-05',
#  'ONGC.BO': '2008-26-05',
#  'POWERGRID.BO': '2008-26-05',
#  'RELIANCE.BO': '2008-26-05',
#  'SBIN.BO': '2008-26-05',
#  'SUNPHARMA.BO': '2008-26-05',
#  'TCS.BO': '2008-26-05',
#  'TECHM.BO': '2008-26-05',
#  'TITAN.BO': '2008-26-05',
#  'ULTRACEMCO.BO': '2008-26-05'}

# %% [markdown]
# ### 4 Calculate 3 month returns of each stock
# - consider the period to be 66 days

# %%
df_mkts_rets_q = df_mkts._______
df_mkts_rets_q.tail()
# Out:
#             ASIANPAINT.BO  AXISBANK.BO  BAJAJ-AUTO.BO  BAJAJFINSV.BO  \
# Date
# 2022-01-17       0.018100    -0.105960      -0.122846       0.006321
# 2022-01-18       0.016447    -0.086376      -0.143708      -0.001650
# 2022-01-19      -0.003617    -0.090274      -0.131521      -0.021604
# 2022-01-20       0.021407    -0.103904      -0.154938      -0.076137
# 2022-01-21       0.029653    -0.110751      -0.124323      -0.142804
#
#             BAJFINANCE.BO  BHARTIARTL.BO  DRREDDY.BO  HCLTECH.BO   HDFC.BO  \
# Date
# 2022-01-17      -0.000617       0.061253   -0.047749    0.015522 -0.019289
# 2022-01-18      -0.022775       0.034703   -0.049034   -0.028340 -0.036894
# 2022-01-19      -0.036943       0.026088   -0.054520   -0.033528 -0.067648
# 2022-01-20      -0.042389       0.051216   -0.057583   -0.021465 -0.085981
# 2022-01-21      -0.046294       0.020631   -0.062900   -0.036161 -0.081403
#
#             HDFCBANK.BO  ...   NTPC.BO   ONGC.BO  POWERGRID.BO  RELIANCE.BO  \
# ...

# %% [markdown]
# ## Re-sample the data by fetching month end value
# - At the end, the dataframe should have rows that show month end pricing data

# %%
df_mkts_returns_month_end = _______________________
df_mkts_returns_month_end.head()
# Out:
#             ASIANPAINT.BO  AXISBANK.BO  BAJAJ-AUTO.BO  BAJAJFINSV.BO  \
# Date
# 2008-05-30            NaN          NaN            NaN            NaN
# 2008-06-30            NaN          NaN            NaN            NaN
# 2008-07-31            NaN          NaN            NaN            NaN
# 2008-08-29      -0.005331    -0.107918       0.010464      -0.161890
# 2008-09-30       0.011649     0.065434       0.275759      -0.358529
#
#             BAJFINANCE.BO  BHARTIARTL.BO  DRREDDY.BO  HCLTECH.BO   HDFC.BO  \
# Date
# 2008-05-30            NaN            NaN         NaN         NaN       NaN
# 2008-06-30            NaN            NaN         NaN         NaN       NaN
# 2008-07-31            NaN            NaN         NaN         NaN       NaN
# 2008-08-29      -0.495446      -0.053583   -0.145810   -0.238755 -0.057420
# 2008-09-30      -0.320968       0.023066   -0.207168   -0.292758 -0.031088
#
#             HDFCBANK.BO  ...   NTPC.BO   ONGC.BO  POWERGRID.BO  RELIANCE.BO  \
# ...

# %% [markdown]
# ## 5) Get top 5 stocks at the end of each month
# - Use the above dataframe and build a new dataframe `df_top5`
# - The new dataframe `df_top5` should contain Date as an index
# - Dataframe contains 5 columns (0,1,2,3,4)
# - Each row outputs the top 5 stock codes at that month end.
# - The logic to get the top 5 stocks is based on the returns we calculated above. Stock with highest return will be 1 and so on

# %%
## Complete this as per the above instructions
## The result should be as shown below
# Out:
#                         0              1              2              3  \
# Date
# 2008-08-29        ONGC.BO       TITAN.BO  HINDUNILVR.BO   SUNPHARMA.BO
# 2008-09-30  BAJAJ-AUTO.BO        ONGC.BO        SBIN.BO  HINDUNILVR.BO
# 2008-10-31  BAJAJ-AUTO.BO  HINDUNILVR.BO   NESTLEIND.BO      MARUTI.BO
# 2008-11-28  HINDUNILVR.BO         ITC.BO        NTPC.BO      MARUTI.BO
# 2008-12-31  HINDUNILVR.BO        NTPC.BO     DRREDDY.BO         ITC.BO
# ...                   ...            ...            ...            ...
# 2021-09-30  BAJAJFINSV.BO       TECHM.BO     HCLTECH.BO        NTPC.BO
# 2021-10-29       TITAN.BO        ONGC.BO       TECHM.BO  BAJAJFINSV.BO
# 2021-11-30        ONGC.BO       TITAN.BO   POWERGRID.BO        NTPC.BO
# 2021-12-31       TECHM.BO       TITAN.BO   POWERGRID.BO   SUNPHARMA.BO
# 2022-01-31       TECHM.BO          LT.BO        INFY.BO   ICICIBANK.BO
#
#                         4
# Date
# 2008-08-29  BAJAJ-AUTO.BO
# 2008-09-30    HDFCBANK.BO
# ...

# %% [markdown]
# ## 6) Now calculate the daily returns of all markets
# - For all the markets in `df_mkts` calculate daily returns.
# - Save the output into a new dataframe `daily_returns`

# %%
# Out:
#             ASIANPAINT.BO  AXISBANK.BO  BAJAJ-AUTO.BO  BAJAJFINSV.BO  \
# Date
# 2022-01-11      -0.005105     0.000875      -0.000116      -0.000595
# 2022-01-12       0.002121     0.004304       0.001062       0.008447
# 2022-01-13      -0.024715    -0.008371       0.003126       0.015573
# 2022-01-14      -0.026600    -0.025392      -0.003956      -0.001366
# 2022-01-17      -0.006821    -0.014967       0.022436       0.006506
#
#             BAJFINANCE.BO  BHARTIARTL.BO  DRREDDY.BO  HCLTECH.BO   HDFC.BO  \
# Date
# 2022-01-11      -0.007724      -0.001561   -0.004889    0.042952  0.019022
# 2022-01-12       0.013561       0.037592    0.004228    0.005246  0.009666
# 2022-01-13       0.003853       0.002055    0.007536   -0.013175  0.006833
# 2022-01-14       0.003614      -0.014831   -0.008030    0.003225 -0.015242
# 2022-01-17       0.003480       0.016928   -0.000896   -0.055587 -0.004551
#
#             HDFCBANK.BO  ...   NTPC.BO   ONGC.BO  POWERGRID.BO  RELIANCE.BO  \
# ...

# %% [markdown]
# ## 7) Building the strategy
# - At this stage you should already have two dataframes ready
#   - `df_top5` - this contains the top 5 stocks at the end of each month
#   - `daily_returns` - this contains the daily returns of all markets.
# - Build a new dataframe called `df_strategy`
#   - For each row in `df_top5` get the stock codes
#   - For each stock fetch the daily returns for each day until the end of month from `daily_returns`
#   - Repeat this step for all the rows in `df_top5`. When the new month starts repeat the same process.
#
# for example, the first row in `df_top5` is,
# 2008-08-29	ONGC.BO	TITAN.BO	HINDUNILVR.BO	SUNPHARMA.BO	BAJAJ-AUTO.BO
#
# The new dataframe `df_strategy` contains daily returns data for these 5 stocks from 2008-09-01 till 2008-09-30
#
# next the second row in `df_top5` is,
# 2008-09-30	BAJAJ-AUTO.BO	ONGC.BO	SBIN.BO	HINDUNILVR.BO	HDFCBANK.BO
#
# now append to `df_strategy` daily returns data for these new 5 stocks from 2008-10-01 till 2008-10-31
#
# Continue this pattern till you reach to the end of `df_top5`

# %%
columns = ['stock_1', 'stock_2', 'stock_3', 'stock_4', 'stock_5']
df_strategy = pd.DataFrame()


df_strategy
# Out:
#              stock_1   stock_2   stock_3   stock_4   stock_5
# Date
# 2008-09-01  0.006352 -0.000669 -0.014059  0.021955 -0.004084
# 2008-09-02  0.069674  0.006337  0.020872  0.015184  0.033237
# 2008-09-04 -0.029686 -0.026713 -0.024899 -0.013128  0.005210
# 2008-09-05  0.001778 -0.010126  0.017646 -0.006949 -0.002057
# 2008-09-08  0.040218 -0.007673  0.027540  0.025559 -0.019042
# ...              ...       ...       ...       ...       ...
# 2022-01-11  0.012493 -0.002314 -0.000490  0.007199  0.002674
# 2022-01-12 -0.005465 -0.014597  0.004659  0.004565  0.011611
# 2022-01-13 -0.005697  0.002354  0.014889  0.035338  0.010332
# 2022-01-14  0.011780 -0.010196 -0.000481 -0.006353  0.016447
# 2022-01-17 -0.001294 -0.001080 -0.002166 -0.003604  0.007753
#
# [3306 rows x 5 columns]

# %% [markdown]
# ## Cummulative return on $1,000 invested in the strategy
# - Time to test your startegy

# %%
# Define the investment
investment = 1000

# Calculate the mean of returns
df_strategy['portfolio_returns'] = df_strategy.mean(axis=1)

# Calculate cumulative returns
returns_plus_one = df_strategy['portfolio_returns'].add(1)
cumulative_return = returns_plus_one.cumprod()

# Calculate and plot investment return
cumulative_return.mul(investment).plot()
plt.show()

# %%
df_strategy['port_value'] = cumulative_return.mul(investment)
df_strategy.head()
# Out:
#              stock_1   stock_2   stock_3   stock_4   stock_5  \
# Date
# 2008-09-01  0.006352 -0.000669 -0.014059  0.021955 -0.004084
# 2008-09-02  0.069674  0.006337  0.020872  0.015184  0.033237
# 2008-09-04 -0.029686 -0.026713 -0.024899 -0.013128  0.005210
# 2008-09-05  0.001778 -0.010126  0.017646 -0.006949 -0.002057
# 2008-09-08  0.040218 -0.007673  0.027540  0.025559 -0.019042
#
#             portfolio_returns   port_value
# Date
# 2008-09-01           0.001899  1001.899045
# 2008-09-02           0.029061  1031.014865
# 2008-09-04          -0.017843  1012.618245
# 2008-09-05           0.000058  1012.677232
# 2008-09-08           0.013320  1026.166395

# %% [markdown]
# # Benchmark returns

# %%
# Download benchmark data from yfinance
benchmark = yf.download(tickers='^BSESN')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Calculate the daily benchmark returns

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6048 entries, 1997-07-01 to 2022-01-19
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bm_returns  6047 non-null   float64
# dtypes: float64(1)
# memory usage: 223.5 KB

# %% [markdown]
# ### Merge benchmark returns with strategy

# %%
df_strategy_final = pd.concat(____________________)
df_strategy_final['bm_returns'] = ## Forward fill NaN

df_strategy_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3306 entries, 2008-09-01 to 2022-01-17
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   stock_1            3306 non-null   float64
#  1   stock_2            3306 non-null   float64
#  2   stock_3            3306 non-null   float64
#  3   stock_4            3306 non-null   float64
#  4   stock_5            3306 non-null   float64
#  5   portfolio_returns  3306 non-null   float64
#  6   port_value         3306 non-null   float64
#  7   bm_returns         3306 non-null   float64
# dtypes: float64(8)
# memory usage: 232.5 KB
# Empty DataFrame
# Columns: [stock_1, stock_2, stock_3, stock_4, stock_5, portfolio_returns, port_value, bm_returns]
# Index: []

# %% [markdown]
# ## Cumulative return on $1,000 invested in benchmark

# %%
# Define the investment
investment = 1000

# Calculate cumulative returns
returns_plus_one_bm = df_strategy_final['bm_returns'].add(1)
cumulative_return_bm = returns_plus_one_bm.cumprod()

# Calculate and plot investment returns
cumulative_return_bm.mul(investment).plot()
plt.show()

# %%
df_strategy_final['bm_value'] = cumulative_return_bm.mul(investment)

# %% [markdown]
# ## Plot both our portfolio returns based on the strategy built above and the benchmark returns
